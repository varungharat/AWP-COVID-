# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid_data = pd.read_csv("covid_19_india.csv")

covid_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
covid_data['State/UnionTerritory'] = covid_data['State/UnionTerritory'].replace('Bihar****','Bihar')
covid_data['State/UnionTerritory'] = covid_data['State/UnionTerritory'].replace('Telengana','Telangana')

# %%
plt.figure(figsize=(12,8))

plt.show()

# %%
covid_data['Date'] = pd.to_datetime(covid_data['Date'])

# %%
covid_data['Year']= covid_data['Date'].dt.year
covid_data['Month']= covid_data['Date'].dt.month
covid_data['Day']= covid_data['Date'].dt.day

# %%
data_2020 = covid_data[covid_data['Year'] == 2020]

data_2020
# Out:
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 10077  10078 2020-12-31  8:00 AM            Telangana                       -
# 10078  10079 2020-12-31  8:00 AM              Tripura                       -
# 10079  10080 2020-12-31  8:00 AM          Uttarakhand                       -
# 10080  10081 2020-12-31  8:00 AM        Uttar Pradesh                       -
# 10081  10082 2020-12-31  8:00 AM          West Bengal                       -
#
# ...

# %%
fig  = plt.figure(figsize=(15,8))
sns.scatterplot(x='Cured',y='State/UnionTerritory',hue='Date',data=data_2020)
plt.tight_layout()
fig.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22124\1630286825.py:3: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# C:\Users\asus\AppData\Local\Temp\ipykernel_22124\1630286825.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data_2021 = covid_data[covid_data['Year'] == 2021]

data_2021
# Out:
#          Sno       Date     Time         State/UnionTerritory  \
# 10082  10083 2021-01-01  8:00 AM               Andhra Pradesh
# 10083  10084 2021-01-01  8:00 AM  Andaman and Nicobar Islands
# 10084  10085 2021-01-01  8:00 AM            Arunachal Pradesh
# 10085  10086 2021-01-01  8:00 AM                        Assam
# 10086  10087 2021-01-01  8:00 AM                        Bihar
# ...      ...        ...      ...                          ...
# 16845  16846 2021-07-07  8:00 AM                    Telangana
# 16846  16847 2021-07-07  8:00 AM                      Tripura
# 16847  16848 2021-07-07  8:00 AM                  Uttarakhand
# 16848  16849 2021-07-07  8:00 AM                Uttar Pradesh
# 16849  16850 2021-07-07  8:00 AM                  West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 10082                       -                        -   871916    7108
# 10083                       -                        -     4826      62
# ...

# %%
sns.set_style(style='whitegrid')
sns.scatterplot(x='Cured',y='State/UnionTerritory',hue="Date",data=data_2021)
plt.tight_layout()
fig.show()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22124\3457297337.py:3: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# C:\Users\asus\AppData\Local\Temp\ipykernel_22124\3457297337.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
sns.set_style(style='darkgrid')
sns.lineplot(x='Confirmed',y='Deaths',data= covid_data)
# Out:
# <AxesSubplot:xlabel='Confirmed', ylabel='Deaths'>

# %%
sns.set_style(style='dark')
sns.lineplot(x='Cured',y='Deaths',data= covid_data)
# Out:
# <AxesSubplot:xlabel='Cured', ylabel='Deaths'>

# %%
sns.set_style(style='whitegrid')
sns.scatterplot(x='Cured',y='Deaths',data= covid_data)
# Out:
# <AxesSubplot:xlabel='Cured', ylabel='Deaths'>

# %%
sns.scatterplot(x='Cured',y='Deaths',hue='State/UnionTerritory',data= covid_data)
# Out:
# <AxesSubplot:xlabel='Cured', ylabel='Deaths'>

# %%
sns.set_style('darkgrid')
sns.histplot(covid_data,x='Cured',hue='State/UnionTerritory',palette='hot')
# Out:
# <AxesSubplot:xlabel='Cured', ylabel='Count'>
# D:\Outlast.2-CODEX\Anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set_style('darkgrid')
sns.histplot(covid_data,x='Cured',hue='State/UnionTerritory',palette='hot')
# Out:
# <AxesSubplot:xlabel='Cured', ylabel='Count'>

# %%
sns.displot(covid_data['Confirmed'])

# %%
sns.displot(covid_data['Cured'])

# %%
sns.displot(covid_data['Deaths'])

# %%
sns.displot(covid_data,x='Confirmed',hue='State/UnionTerritory')

# %%
sns.displot(covid_data,x='Cured',hue='State/UnionTerritory')

# %%
sns.displot(covid_data,x='Deaths',hue='State/UnionTerritory')

# %%
sns.catplot(data=covid_data,x='Cured',y='Deaths',kind='box')

# %%
sns.catplot(data=covid_data,x='Cured',kind='box')
